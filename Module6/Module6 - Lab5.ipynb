# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module6- Lab5

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Useful information about the dataset used in this assignment can be [found here](https://archive.ics.uci.edu/ml/machine-learning-databases/mushroom/agaricus-lepiota.names).

# %% [markdown]
# Load up the mushroom dataset into dataframe `X` and verify you did it properly, and that you have not included any features that clearly shouldn't be part of the dataset.
#
# You should not have any doubled indices. You can check out information about the headers present in the dataset using the link we provided above. Also make sure you've properly captured any NA values.

# %%
# .. your code here ..
X = pd.read_csv('Datasets/agaricus-lepiota.data', names = ['classification','cap-shape','cap-surface','cap-color','bruises?','odor','gill-attachment','gill-spacing','gill-size','gill-color','stalk-shape','stalk-root','stalk-surface-above-ring' 
,'stalk-surface-below-ring','stalk-color-above-ring','stalk-color-below-ring' ,'veil-type','veil-color','ring-number' ,'ring-type','spore-print-color','population','habitat'])
X = X.replace('?', np.nan)
X.shape
# Out:
# (8124, 23)

# %%
# An easy way to show which rows have nans in them:
X[pd.isnull(X).any(axis=1)]
# Out:
#      classification cap-shape cap-surface cap-color bruises? odor  \
# 3984              e         x           y         b        t    n
# 4023              p         x           y         e        f    y
# 4076              e         f           y         u        f    n
# 4100              p         x           y         e        f    y
# 4104              p         x           y         n        f    f
# 4196              p         x           y         n        f    y
# 4200              p         x           y         n        f    y
# 4283              e         f           s         p        t    n
# 4291              e         k           s         p        t    n
# 4326              e         x           y         r        f    n
# 4329              p         x           y         n        f    s
# 4331              p         k           y         n        f    n
# 4357              e         x           s         e        t    n
# 4376              p         x           y         n        f    y
# 4380              e         x           y         b        t    n
# 4396              e         x           y         u        f    n
# 4419              e         x           s         b        t    n
# 4429              p         x           y         n        f    y
# 4459              e         k           y         b        t    n
# 4461              p         x           y         n        f    s
# 4494              p         f           f         y        f    n
# 4497              e         f           s         n        t    n
# 4498              p         x           y         n        f    y
# 4519              e         x           s         b        t    n
# 4522              p         x           y         n        f    s
# 4533              e         x           y         u        f    n
# 4534              e         f           y         b        t    n
# 4557              e         x           y         u        f    n
# 4610              p         x           y         n        f    y
# 4611              e         f           y         b        t    n
# ...             ...       ...         ...       ...      ...  ...
# 8092              p         k           y         e        f    y
# 8093              p         x           s         n        f    y
# 8094              e         b           s         g        f    n
# 8096              e         k           f         w        f    n
# 8097              p         k           y         n        f    s
# 8098              p         k           s         e        f    y
# 8099              e         k           f         w        f    n
# 8100              e         f           s         n        f    n
# 8101              p         k           s         e        f    s
# 8102              e         x           s         n        f    n
# 8103              e         k           s         n        f    n
# 8104              e         k           s         n        f    n
# 8105              e         k           s         n        f    n
# 8106              e         k           s         n        f    n
# 8107              e         x           s         n        f    n
# 8108              p         k           y         e        f    y
# 8109              e         b           s         w        f    n
# 8110              e         x           s         n        f    n
# 8111              e         k           s         w        f    n
# 8112              e         k           s         n        f    n
# 8113              p         k           y         e        f    y
# 8115              e         x           s         n        f    n
# 8116              p         k           y         n        f    s
# 8117              p         k           s         e        f    y
# 8118              p         k           y         n        f    f
# 8119              e         k           s         n        f    n
# 8120              e         x           s         n        f    n
# 8121              e         f           s         n        f    n
# 8122              p         k           y         n        f    y
# 8123              e         x           s         n        f    n
#
#      gill-attachment gill-spacing gill-size gill-color   ...    \
# 3984               f            c         b          e   ...
# 4023               f            c         n          b   ...
# 4076               f            c         n          h   ...
# 4100               f            c         n          b   ...
# 4104               f            c         n          b   ...
# 4196               f            c         n          b   ...
# 4200               f            c         n          b   ...
# 4283               f            c         b          e   ...
# 4291               f            c         b          e   ...
# 4326               f            c         n          p   ...
# 4329               f            c         n          b   ...
# 4331               f            c         n          w   ...
# 4357               f            c         b          e   ...
# 4376               f            c         n          b   ...
# 4380               f            c         b          e   ...
# 4396               f            c         n          h   ...
# 4419               f            c         b          e   ...
# 4429               f            c         n          b   ...
# 4459               f            c         b          e   ...
# 4461               f            c         n          b   ...
# 4494               f            c         n          w   ...
# 4497               f            c         b          e   ...
# 4498               f            c         n          b   ...
# 4519               f            c         b          w   ...
# 4522               f            c         n          b   ...
# 4533               f            c         n          h   ...
# 4534               f            c         b          e   ...
# 4557               f            c         n          u   ...
# 4610               f            c         n          b   ...
# 4611               f            c         b          w   ...
# ...              ...          ...       ...        ...   ...
# 8092               f            c         n          b   ...
# 8093               f            c         n          b   ...
# 8094               f            w         b          g   ...
# 8096               f            w         b          w   ...
# 8097               f            c         n          b   ...
# 8098               f            c         n          b   ...
# 8099               f            w         b          w   ...
# 8100               a            c         b          o   ...
# 8101               f            c         n          b   ...
# 8102               a            c         b          y   ...
# 8103               a            c         b          y   ...
# 8104               a            c         b          y   ...
# 8105               a            c         b          y   ...
# 8106               a            c         b          o   ...
# 8107               a            c         b          y   ...
# 8108               f            c         n          b   ...
# 8109               f            w         b          w   ...
# 8110               a            c         b          o   ...
# 8111               f            w         b          p   ...
# 8112               a            c         b          o   ...
# 8113               f            c         n          b   ...
# 8115               a            c         b          y   ...
# 8116               f            c         n          b   ...
# 8117               f            c         n          b   ...
# 8118               f            c         n          b   ...
# 8119               a            c         b          y   ...
# 8120               a            c         b          y   ...
# 8121               a            c         b          n   ...
# 8122               f            c         n          b   ...
# 8123               a            c         b          y   ...
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 3984                        s                      e                      w
# 4023                        s                      w                      w
# 4076                        f                      w                      w
# 4100                        s                      p                      p
# 4104                        s                      p                      p
# 4196                        k                      p                      p
# 4200                        k                      p                      w
# 4283                        s                      w                      w
# 4291                        s                      w                      e
# 4326                        f                      w                      w
# 4329                        s                      w                      w
# 4331                        y                      w                      n
# 4357                        s                      w                      e
# 4376                        k                      w                      p
# 4380                        s                      w                      e
# 4396                        f                      w                      w
# 4419                        s                      w                      w
# 4429                        s                      w                      p
# 4459                        s                      e                      e
# 4461                        k                      p                      w
# 4494                        y                      w                      y
# 4497                        s                      w                      w
# 4498                        k                      p                      p
# 4519                        s                      e                      w
# 4522                        s                      p                      p
# 4533                        f                      w                      w
# 4534                        s                      e                      e
# 4557                        f                      w                      w
# 4610                        s                      p                      w
# 4611                        s                      w                      w
# ...                       ...                    ...                    ...
# 8092                        s                      p                      p
# 8093                        k                      w                      w
# 8094                        s                      w                      w
# 8096                        s                      w                      w
# 8097                        k                      p                      p
# 8098                        k                      w                      p
# 8099                        k                      w                      w
# 8100                        s                      o                      o
# 8101                        s                      p                      w
# 8102                        s                      o                      o
# 8103                        s                      o                      o
# 8104                        s                      o                      o
# 8105                        s                      o                      o
# 8106                        s                      o                      o
# 8107                        s                      o                      o
# 8108                        s                      p                      w
# 8109                        s                      w                      w
# 8110                        s                      o                      o
# 8111                        s                      w                      w
# 8112                        s                      o                      o
# 8113                        k                      p                      p
# 8115                        s                      o                      o
# 8116                        k                      p                      w
# 8117                        s                      p                      w
# 8118                        s                      p                      w
# 8119                        s                      o                      o
# 8120                        s                      o                      o
# 8121                        s                      o                      o
# 8122                        k                      w                      w
# 8123                        s                      o                      o
#
#      veil-type veil-color ring-number ring-type spore-print-color population  \
# 3984         p          w           t         e                 w          c
# 4023         p          w           o         e                 w          v
# 4076         p          w           o         f                 h          y
# 4100         p          w           o         e                 w          v
# 4104         p          w           o         e                 w          v
# 4196         p          w           o         e                 w          v
# 4200         p          w           o         e                 w          v
# 4283         p          w           t         e                 w          c
# 4291         p          w           t         e                 w          c
# 4326         p          w           o         f                 h          v
# 4329         p          w           o         e                 w          v
# 4331         p          w           o         e                 w          v
# 4357         p          w           t         e                 w          c
# 4376         p          w           o         e                 w          v
# 4380         p          w           t         e                 w          c
# 4396         p          w           o         f                 h          y
# 4419         p          w           t         e                 w          c
# 4429         p          w           o         e                 w          v
# 4459         p          w           t         e                 w          c
# 4461         p          w           o         e                 w          v
# 4494         p          w           o         e                 w          v
# 4497         p          w           t         e                 w          c
# 4498         p          w           o         e                 w          v
# 4519         p          w           t         e                 w          c
# 4522         p          w           o         e                 w          v
# 4533         p          w           o         f                 h          v
# 4534         p          w           t         e                 w          c
# 4557         p          w           o         f                 h          v
# 4610         p          w           o         e                 w          v
# 4611         p          w           t         e                 w          c
# ...        ...        ...         ...       ...               ...        ...
# 8092         p          w           o         e                 w          v
# 8093         p          w           o         e                 w          v
# 8094         p          w           t         p                 w          n
# 8096         p          w           t         p                 w          n
# 8097         p          w           o         e                 w          v
# 8098         p          w           o         e                 w          v
# 8099         p          w           t         p                 w          s
# 8100         p          n           o         p                 b          v
# 8101         p          w           o         e                 w          v
# 8102         p          n           o         p                 n          c
# 8103         p          n           o         p                 o          c
# 8104         p          o           o         p                 n          v
# 8105         p          n           o         p                 y          v
# 8106         p          o           o         p                 n          v
# 8107         p          o           o         p                 n          c
# 8108         p          w           o         e                 w          v
# 8109         p          w           t         p                 w          n
# 8110         p          o           o         p                 n          v
# 8111         p          w           t         p                 w          n
# 8112         p          n           o         p                 b          v
# 8113         p          w           o         e                 w          v
# 8115         p          o           o         p                 o          v
# 8116         p          w           o         e                 w          v
# 8117         p          w           o         e                 w          v
# 8118         p          w           o         e                 w          v
# 8119         p          o           o         p                 b          c
# 8120         p          n           o         p                 b          v
# 8121         p          o           o         p                 b          c
# 8122         p          w           o         e                 w          v
# 8123         p          o           o         p                 o          c
#
#      habitat
# 3984       w
# 4023       p
# 4076       d
# 4100       d
# 4104       l
# 4196       d
# 4200       l
# 4283       w
# 4291       w
# 4326       d
# 4329       p
# 4331       d
# 4357       w
# 4376       d
# 4380       w
# 4396       d
# 4419       w
# 4429       d
# 4459       w
# 4461       d
# 4494       d
# 4497       w
# 4498       p
# 4519       w
# 4522       l
# 4533       d
# 4534       w
# 4557       d
# 4610       d
# 4611       w
# ...      ...
# 8092       p
# 8093       d
# 8094       g
# 8096       g
# 8097       l
# 8098       d
# 8099       g
# 8100       l
# 8101       p
# 8102       l
# 8103       l
# 8104       l
# 8105       l
# 8106       l
# 8107       l
# 8108       l
# 8109       g
# 8110       l
# 8111       g
# 8112       l
# 8113       d
# 8115       l
# 8116       l
# 8117       d
# 8118       d
# 8119       l
# 8120       l
# 8121       l
# 8122       l
# 8123       l
#
# [2480 rows x 23 columns]

# %% [markdown]
# For this simple assignment, just drop any row with a nan in it, and then print out your dataset's shape:

# %%
# .. your code here ..
X.dropna(axis=0, inplace=True)
X.shape
# Out:
# (5644, 23)

# %% [markdown]
# Copy the labels out of the dataframe into variable `y`, then remove them from `X`.
#
# Encode the labels, using the `.map()` trick we presented you in Module 5, using `canadian:0`, `kama:1`, and `rosa:2`.

# %%
# .. your code here ..
y = X.classification.copy()
X.drop(['classification'], axis=1, inplace=True)

# %% [markdown]
# Encode the entire dataframe using dummies:

# %%
X = pd.get_dummies(X,columns=X.columns.tolist())

# %% [markdown]
# Split your data into `test` and `train` sets. Your `test` size should be 30% with `random_state` 7.
#
# Please use variable names: `X_train`, `X_test`, `y_train`, and `y_test`:

# %%
# .. your code here ..
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)

# %% [markdown]
# Create an DT classifier. No need to set any parameters:

# %%
# .. your code here ..
from sklearn import tree

dt = tree.DecisionTreeClassifier()

# %% [markdown]
# Train the classifier on the `training` data and labels; then, score the classifier on the `testing` data and labels:

# %%
# .. your code here ..
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
for name, importance in zip(X.columns, dt.feature_importances_):
    print(name, importance)
# Out:
# cap-shape_b 0.0
# cap-shape_c 0.0
# cap-shape_f 0.0
# cap-shape_k 0.0
# cap-shape_s 0.0
# cap-shape_x 0.0
# cap-surface_f 0.0
# cap-surface_g 0.0
# cap-surface_s 0.0
# cap-surface_y 0.0
# cap-color_b 0.0
# cap-color_c 0.0
# cap-color_e 0.0
# cap-color_g 0.0
# cap-color_n 0.0
# cap-color_p 0.0
# cap-color_w 0.0
# cap-color_y 0.0
# bruises?_f 0.0
# bruises?_t 0.0
# odor_a 0.0
# odor_c 0.0
# odor_f 0.0
# odor_l 0.0
# odor_m 0.0
# odor_n 0.048931015305104575
# odor_p 0.0
# gill-attachment_a 0.0
# gill-attachment_f 0.0
# gill-spacing_c 0.0
# gill-spacing_w 0.0
# gill-size_b 0.0
# gill-size_n 0.16219328833575347
# gill-color_g 0.0
# gill-color_h 0.0
# gill-color_k 0.0
# gill-color_n 0.0
# gill-color_p 0.0
# gill-color_r 0.0
# gill-color_u 0.0
# gill-color_w 0.0
# gill-color_y 0.0
# stalk-shape_e 0.058310125302328486
# stalk-shape_t 0.0
# stalk-root_b 0.0
# stalk-root_c 0.0
# stalk-root_e 0.0
# stalk-root_r 0.0
# stalk-surface-above-ring_f 0.0
# stalk-surface-above-ring_k 0.0
# stalk-surface-above-ring_s 0.0
# stalk-surface-above-ring_y 0.0
# stalk-surface-below-ring_f 0.0
# stalk-surface-below-ring_k 0.0
# stalk-surface-below-ring_s 0.0
# stalk-surface-below-ring_y 0.0
# stalk-color-above-ring_b 0.0
# stalk-color-above-ring_c 0.0
# stalk-color-above-ring_g 0.0
# stalk-color-above-ring_n 0.0
# stalk-color-above-ring_p 0.0
# stalk-color-above-ring_w 0.0
# stalk-color-above-ring_y 0.0
# stalk-color-below-ring_b 0.0
# stalk-color-below-ring_c 0.0
# stalk-color-below-ring_g 0.0
# stalk-color-below-ring_n 0.0
# stalk-color-below-ring_p 0.0
# stalk-color-below-ring_w 0.0
# stalk-color-below-ring_y 0.0
# veil-type_p 0.0
# veil-color_w 0.0
# veil-color_y 0.0
# ring-number_n 0.0
# ring-number_o 0.057989438419944216
# ring-number_t 0.0
# ring-type_e 0.0
# ring-type_l 0.0
# ring-type_n 0.0
# ring-type_p 0.0
# spore-print-color_h 0.6384897334245091
# spore-print-color_k 0.0
# spore-print-color_n 0.0
# spore-print-color_r 0.0
# spore-print-color_u 0.0
# spore-print-color_w 0.0
# population_a 0.0
# population_c 0.010718814961866253
# population_n 0.0
# population_s 0.0
# population_v 0.0
# population_y 0.004103575770818449
# habitat_d 0.0
# habitat_g 0.0
# habitat_l 0.0
# habitat_m 0.0
# habitat_p 0.019264008479675503
# habitat_u 0.0

# %%
score = dt.score(X_test, y_test)

# %%
print("High-Dimensionality Score: ", round((score*100), 3))
# Out:
# High-Dimensionality Score:  100.0

# %% [markdown]
# Use the code on the course's SciKit-Learn page to output a .DOT file, then render the .DOT to .PNGs.
#
# You will need graphviz installed to do this. On macOS, you can `brew install graphviz`. On Windows 10, graphviz installs via a .msi installer that you can download from the graphviz website. Also, a graph editor, gvedit.exe can be used to view the tree directly from the exported tree.dot file without having to issue a call. On other systems, use analogous commands.
#
# If you encounter issues installing graphviz or don't have the rights to, you can always visualize your .dot file on the website: http://webgraphviz.com/.

# %%
tree.export_graphviz(dt.tree_, out_file='tree.dot', feature_names=X.columns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-8e1e333b1290> in <module>()
# ----> 1 tree.export_graphviz(dt.tree_, out_file='tree.dot', feature_names=X.columns)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\tree\export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision)
#     390                 out_file.write('%d -> %d ;\n' % (parent, node_id))
#     391
# --> 392     check_is_fitted(decision_tree, 'tree_')
#     393     own_file = False
#     394     return_string = False
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     760
#     761     if not hasattr(estimator, 'fit'):
# --> 762         raise TypeError("%s is not an estimator instance." % (estimator))
#     763
#     764     if not isinstance(attributes, (list, tuple)):
#
# TypeError: <sklearn.tree._tree.Tree object at 0x0000015C86D7C850> is not an estimator instance.

# %%
sum([40
,20
,10
,22
,10
,4
,120
,5
,6
,10
,45
,20
,8
,7
,7
,65
,77
,6
,14
,8
,25
,65
,112
,20
,15
,40
,60
,8
,5
,240
,20
,5
,80
,34
,17
,5
,30
,11
,5
,5
,16
,65
,46
,10
,4
,5
,10
,30
,10
,6
,45
,7
,488
,960])
# Out:
# 3008

# %%
sum([960, 30, 112, 65])
# Out:
# 1167
